# %%
import pandas as pd
from pathlib import Path
import shutil
import random

# --- INPUT PATHS ---
csv_in = Path(r"D:\vc-research\vc-research\Reese's contributions\reese data\downloaded_batches\combined_extracted_dataAICoded.csv")
csv_out = Path(r"D:\vc-research\vc-research\Reese's contributions\reese data\downloaded_batches\combined_extracted_dataAICHECKSAMPLE.csv")

batch_dirs = [
    Path(r"D:\vc-research\vc-research\Batch1"),
    Path(r"D:\vc-research\vc-research\Batch2"),
    Path(r"D:\vc-research\vc-research\Batch3"),
    Path(r"D:\vc-research\vc-research\Batch4"),
]
dest_dir = Path(r"D:\vc-research\vc-research\BatchAISAMPLE")
dest_dir.mkdir(parents=True, exist_ok=True)

# --- PARAMETERS ---
SAMPLE_N = 200
RANDOM_SEED = 45  # set to an int (e.g., 42) if you want reproducible sampling

# --- STEP 1: Read CSV and randomly select 200 rows ---
df = pd.read_csv(csv_in, dtype=str)  # read all as string to protect IDs
if len(df) < SAMPLE_N:
    raise ValueError(f"CSV has only {len(df)} rows; cannot sample {SAMPLE_N}.")

df_sample = df.sample(n=SAMPLE_N, random_state=RANDOM_SEED)
df_sample.to_csv(csv_out, index=False)

# --- STEP 2: Build filename list from 'custom_id' ---
if "custom_id" not in df_sample.columns:
    raise KeyError("Column 'custom_id' not found in the CSV.")

def transform_id(s: str) -> str | None:
    if pd.isna(s):
        return None
    s = str(s)
    # remove first 8 chars and last 9 chars
    if len(s) < 17:  # must be at least 8 + 9
        return None
    return s[8:-9]

names = [transform_id(x) for x in df_sample["custom_id"]]
# keep only valid, non-empty names
names = [n for n in names if n and n.strip()]
# Dedup & normalize case for matching on Windows
name_set = {n.strip().lower() for n in names}

# Also save the list for reference
names_txt = dest_dir / "sample_filenames_list.txt"
with names_txt.open("w", encoding="utf-8") as f:
    for n in sorted(name_set):
        f.write(n + "\n")

# --- STEP 3: Index all files in Batch1–Batch4 by stem (case-insensitive) ---
# We’ll map normalized stem -> list of file Paths (in case the same name appears in multiple dirs)
from collections import defaultdict
index = defaultdict(list)

for bdir in batch_dirs:
    if not bdir.exists():
        continue
    for p in bdir.rglob("*"):
        if p.is_file():
            stem_norm = p.stem.lower()
            index[stem_norm].append(p)

# --- STEP 4: Copy matches to destination, avoiding overwrites ---
def safe_copy(src: Path, dst_folder: Path):
    """
    Copy src to dst_folder, preserving extension, avoiding overwrite by appending suffixes.
    Returns the final destination path.
    """
    candidate = dst_folder / src.name
    if not candidate.exists():
        shutil.copy2(src, candidate)
        return candidate
    # add incremental suffix: filename_1.ext, filename_2.ext, ...
    stem, ext = src.stem, src.suffix
    i = 1
    while True:
        c2 = dst_folder / f"{stem}_{i}{ext}"
        if not c2.exists():
            shutil.copy2(src, c2)
            return c2
        i += 1

copied = []
missing = []

for target_name in name_set:
    if target_name in index:
        for src_path in index[target_name]:
            dst_path = safe_copy(src_path, dest_dir)
            copied.append(dst_path)
    else:
        missing.append(target_name)

# --- Optional: brief console report ---
print(f"Sampled {len(df_sample)} rows and saved to:\n  {csv_out}")
print(f"Filename list written to:\n  {names_txt}")
print(f"Copied {len(copied)} files to:\n  {dest_dir}")
if missing:
    print(f"{len(missing)} names had no matching files in Batch1–4. "
          f"First few: {missing[:10]}")
# Out:
# Sampled 200 rows and saved to:
#   D:\vc-research\vc-research\Reese's contributions\reese data\downloaded_batches\combined_extracted_dataAICHECKSAMPLE.csv
# Filename list written to:
#   D:\vc-research\vc-research\BatchAISAMPLE\sample_filenames_list.txt
# Copied 200 files to:
#   D:\vc-research\vc-research\BatchAISAMPLE

# %%
#Yash stuff
import shutil
from pathlib import Path

# --- INPUTS ---
checklist_path = Path(r"D:\vc-research\vc-research\Reese's contributions\reese data\checkedlist.txt")
search_dirs = [
    Path(r"D:\vc-research\vc-research\Batch1"),
    Path(r"D:\vc-research\vc-research\Batch2"),
    Path(r"D:\vc-research\vc-research\Batch3"),
    Path(r"D:\vc-research\vc-research\Batch4"),
]
dest_dir = Path(r"D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs")

# --- HELPERS ---
def transform_name(raw_line: str) -> str | None:
    """
    For a line like 'checked_XXXX...YYYY', remove the leading 'checked_' (if present)
    and then drop the last 9 characters. Returns the resulting base name (no extension).
    """
    s = raw_line.strip()
    if not s:
        return None
    if s.startswith("checked_"):
        s = s[len("checked_"):]
    if len(s) < 9:
        return None  # can't drop last 9 safely
    s = s[:-9]
    # Remove a trailing extension if present; we will compare to PDF stems anyway.
    if "." in s:
        s = Path(s).stem
    return s

def unique_destination(base: Path) -> Path:
    """
    If 'base' exists, append _1, _2, ... before the extension to avoid overwrite.
    """
    if not base.exists():
        return base
    i = 1
    while True:
        candidate = base.with_stem(f"{base.stem}_{i}")
        if not candidate.exists():
            return candidate
        i += 1

# --- MAIN ---
def main():
    dest_dir.mkdir(parents=True, exist_ok=True)

    # Read and transform checklist lines into desired stems (casefold for robust matching)
    with checklist_path.open("r", encoding="utf-8-sig") as f:
        targets = [t for t in (transform_name(line) for line in f) if t]

    target_set = {t.casefold() for t in targets}  # case-insensitive matching

    # Build an index of all PDFs across search directories: {stem_lower: [paths]}
    stem_to_paths: dict[str, list[Path]] = {}
    for root in search_dirs:
        if not root.exists():
            print(f"WARNING: Search directory not found: {root}")
            continue
        for pdf in root.rglob("*.pdf"):
            stem_lower = pdf.stem.casefold()
            stem_to_paths.setdefault(stem_lower, []).append(pdf)

    # Copy matches
    copied = 0
    missing = []
    multi = 0

    for stem_lower in target_set:
        matches = stem_to_paths.get(stem_lower, [])
        if not matches:
            missing.append(stem_lower)
            continue

        # If multiple PDFs share the same stem, copy them all (from different folders)
        if len(matches) > 1:
            multi += 1

        for src in matches:
            out = dest_dir / src.name
            out = unique_destination(out)  # avoid overwriting if duplicate names
            shutil.copy2(src, out)
            copied += 1
            print(f"Copied: {src} -> {out}")

    print("\n--- SUMMARY ---")
    print(f"Requested stems: {len(target_set)}")
    print(f"PDFs copied:     {copied}")
    print(f"Stems missing:   {len(missing)}")
    if missing:
        # Show a few for quick inspection
        preview = ", ".join(sorted(missing)[:15])
        print(f"Missing (sample): {preview}{' ...' if len(missing) > 15 else ''}")
    print(f"Stems with multiple source PDFs: {multi}")

if __name__ == "__main__":
    main()
# Out:
# Copied: D:\vc-research\vc-research\Batch2\110_2010-02-09_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\110_2010-02-09_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\188_2014-04-14_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\188_2014-04-14_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\560_2010-05-28_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\560_2010-05-28_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\640_2006-02-07_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\640_2006-02-07_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\166_2003-11-05_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\166_2003-11-05_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\890_2006-06-19_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\890_2006-06-19_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\45_2008-01-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\45_2008-01-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\130_2007-12-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\130_2007-12-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\6502_2009-12-02_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\6502_2009-12-02_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\4051_2006-03-16_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\4051_2006-03-16_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\4342_2016-12-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\4342_2016-12-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\260_2007-04-09_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\260_2007-04-09_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\399_2007-10-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\399_2007-10-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\957_2008-05-29_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\957_2008-05-29_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\4755_2004-01-21_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\4755_2004-01-21_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\957_2011-08-25_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\957_2011-08-25_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\991_2011-12-02_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\991_2011-12-02_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\233_2011-02-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\233_2011-02-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\654_2009-01-05_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\654_2009-01-05_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\3873_2010-11-30_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\3873_2010-11-30_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\2540_2015-03-25_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\2540_2015-03-25_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\341_2006-12-15_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\341_2006-12-15_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\28_2009-12-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\28_2009-12-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\657_2005-04-18_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\657_2005-04-18_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\424_2010-10-08_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\424_2010-10-08_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\647_1999-04-29_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\647_1999-04-29_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\155_2010-11-10_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\155_2010-11-10_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\48_2005-04-11_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\48_2005-04-11_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\511_2008-12-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\511_2008-12-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\560_2010-12-22_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\560_2010-12-22_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\939_2013-09-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\939_2013-09-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\706_2005-07-22_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\706_2005-07-22_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\2276_2011-01-28_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\2276_2011-01-28_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\7671_1996-08-19_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\7671_1996-08-19_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\982_2004-10-29_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\982_2004-10-29_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\4757_2010-10-20_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\4757_2010-10-20_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\246_2005-12-28_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\246_2005-12-28_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\825_2008-10-28_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\825_2008-10-28_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\155_2001-12-20_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\155_2001-12-20_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\7571_2001-08-02_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\7571_2001-08-02_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\382_2004-12-30_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\382_2004-12-30_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\48_2014-03-06_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\48_2014-03-06_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\422_2007-07-20_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\422_2007-07-20_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\150_2007-01-19_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\150_2007-01-19_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\647_2010-10-04_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\647_2010-10-04_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\754_2014-12-08_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\754_2014-12-08_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\825_2005-12-02_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\825_2005-12-02_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\810_2006-04-20_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\810_2006-04-20_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\7599_2006-09-01_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\7599_2006-09-01_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\2780_2007-06-08_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\2780_2007-06-08_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\3217_2007-10-30_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\3217_2007-10-30_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\6656_2006-06-06_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\6656_2006-06-06_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\8877_2007-11-16_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\8877_2007-11-16_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\330_2014-04-24_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\330_2014-04-24_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\27_2002-09-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\27_2002-09-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\367_2014-09-15_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\367_2014-09-15_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\6467_2012-02-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\6467_2012-02-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\24_2009-06-12_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\24_2009-06-12_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\4266_2005-03-24_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\4266_2005-03-24_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\608_1998-11-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\608_1998-11-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\587_2012-11-15_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\587_2012-11-15_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\825_2013-11-08_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\825_2013-11-08_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\81_2010-03-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\81_2010-03-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\908_2007-01-25_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\908_2007-01-25_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\550_2006-01-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\550_2006-01-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\6082_2005-01-24_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\6082_2005-01-24_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\234_2009-11-18_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\234_2009-11-18_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\780_2005-03-21_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\780_2005-03-21_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\900_2007-08-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\900_2007-08-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\5729_2009-03-03_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\5729_2009-03-03_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\6458_2005-07-26_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\6458_2005-07-26_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\533_2004-08-16_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\533_2004-08-16_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\657_2003-01-09_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\657_2003-01-09_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\873_2007-03-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\873_2007-03-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\4557_2008-01-04_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\4557_2008-01-04_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\937_2006-05-11_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\937_2006-05-11_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\525_2008-07-24_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\525_2008-07-24_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\3775_2016-03-22_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\3775_2016-03-22_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\166_2007-12-20_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\166_2007-12-20_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\607_2016-09-21_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\607_2016-09-21_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\605_2005-12-21_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\605_2005-12-21_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\234_2009-10-07_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\234_2009-10-07_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\500_2011-04-15_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\500_2011-04-15_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\564_2008-08-19_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\564_2008-08-19_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\359_2004-02-12_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\359_2004-02-12_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\423_2006-10-10_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\423_2006-10-10_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\816_2014-05-01_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\816_2014-05-01_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\367_2015-02-05_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\367_2015-02-05_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\3423_2006-03-03_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\3423_2006-03-03_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\862_2006-11-27_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\862_2006-11-27_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\944_2007-10-24_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\944_2007-10-24_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\65_2010-04-05_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\65_2010-04-05_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\731_2008-02-22_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\731_2008-02-22_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\6582_2002-02-12_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\6582_2002-02-12_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\549_2008-08-11_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\549_2008-08-11_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\2118_2001-06-08_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\2118_2001-06-08_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\155_2004-09-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\155_2004-09-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\188_2013-09-26_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\188_2013-09-26_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\3873_2000-07-31_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\3873_2000-07-31_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\296_2008-07-29_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\296_2008-07-29_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\1373_2009-12-10_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\1373_2009-12-10_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\1308_2007-11-26_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\1308_2007-11-26_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\397_2010-01-26_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\397_2010-01-26_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\957_2007-10-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\957_2007-10-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\802_2003-06-11_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\802_2003-06-11_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\2691_2006-06-27_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\2691_2006-06-27_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\7571_2008-07-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\7571_2008-07-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\3775_2006-07-12_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\3775_2006-07-12_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\155_2016-09-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\155_2016-09-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\6519_2010-08-05_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\6519_2010-08-05_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\244_2010-11-12_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\244_2010-11-12_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\16_2003-07-03_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\16_2003-07-03_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\832_2008-06-30_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\832_2008-06-30_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\328_2006-02-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\328_2006-02-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\2540_2014-01-10_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\2540_2014-01-10_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\650_2007-03-26_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\650_2007-03-26_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\862_2011-04-15_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\862_2011-04-15_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\192_2007-02-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\192_2007-02-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\5447_2015-02-26_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\5447_2015-02-26_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\236_2008-05-15_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\236_2008-05-15_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\8668_2007-06-29_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\8668_2007-06-29_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\569_2005-06-14_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\569_2005-06-14_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\766_2004-03-29_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\766_2004-03-29_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\661_2012-02-14_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\661_2012-02-14_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\221_2007-06-12_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\221_2007-06-12_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\376_2007-02-06_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\376_2007-02-06_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\27_2006-08-23_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\27_2006-08-23_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\731_2009-04-06_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\731_2009-04-06_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\875_2006-12-21_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\875_2006-12-21_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\6661_2011-11-15_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\6661_2011-11-15_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\8257_2008-11-12_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\8257_2008-11-12_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\3504_2003-01-17_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\3504_2003-01-17_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\49_2006-01-30_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\49_2006-01-30_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\618_2014-01-30_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\618_2014-01-30_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\618_2011-04-15_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\618_2011-04-15_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\100_2008-12-03_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\100_2008-12-03_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\590_2004-02-20_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\590_2004-02-20_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\364_2003-08-25_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\364_2003-08-25_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\717_2006-04-27_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\717_2006-04-27_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\625_2004-10-26_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\625_2004-10-26_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch4\screwedupprocessed\7523_2007-06-28_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\7523_2007-06-28_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\613_2006-08-04_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\613_2006-08-04_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\100_2007-02-22_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\100_2007-02-22_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\849_2007-08-03_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\849_2007-08-03_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\1738_2006-10-16_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\1738_2006-10-16_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\188_2006-06-22_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\188_2006-06-22_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\1944_2007-05-10_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\1944_2007-05-10_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch3\1092_2006-07-07_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\1092_2006-07-07_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\650_2008-04-02_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\650_2008-04-02_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\867_2010-09-09_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\867_2010-09-09_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch2\155_2007-01-03_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\155_2007-01-03_Certificates of Incorporation.pdf
# Copied: D:\vc-research\vc-research\Batch1\24_2009-07-20_Certificates of Incorporation.pdf -> D:\vc-research\vc-research\Reese's contributions\reese data\YashPDFs\24_2009-07-20_Certificates of Incorporation.pdf
#
# --- SUMMARY ---
# Requested stems: 152
# PDFs copied:     152
# Stems missing:   0
# Stems with multiple source PDFs: 0
