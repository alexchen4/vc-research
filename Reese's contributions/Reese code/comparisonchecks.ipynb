# %%
createdfile = r"D:\vc-research\vc-research\Reese's contributions\reese data\downloaded_batches\combined_extracted_dataAICoded.csv"
#createdfile = r"D:\vc-research\reese data\batches\batch2\downloads\combined_extracted_datafuck.csv"
#priorfile = r"D:\vc-research\VC Research (Batch 1) - Batch 1 Main.csv"

priorfile = r"D:\vc-research\VC Research (Batch 2) - Batch 2 Main.csv"

# %%
import pandas as pd
import re
import numpy as np

def clean_custom_id(value):
    """Strip 'checked_' prefix and trailing 8-digit hash from ID strings."""
    if isinstance(value, str):
        value = re.sub(r'^checked_', '', value)
        value = re.sub(r'_[a-f0-9]{8}$', '', value)
    return value

def strip_commas(val, na_dict=None):
    """
    Remove commas and whitespace from value, try converting to float.
    If the cleaned string is in na_dict, return the mapped value (e.g., 0.0, np.nan, etc.)
    """
    if pd.isna(val):
        return val

    val_str = str(val).replace(",", "").strip()

    # If value is in the mapping, return the mapped value
    if na_dict and val_str in na_dict:
        return na_dict[val_str]

    try:
        return float(val_str)
    except ValueError:
        return val_str


def compare_fields(file1, file2, field1, field2,
                   id_field1, id_field2,
                   file1_is_df=False, file2_is_df=False,
                   clean_key_field_in=None,
                   na_dict=None):
    """
    Compare two fields from two datasets using specified ID fields.
    Cleans fields in-place before merge. Compares cleaned values.
    """

    # Load files
    df1 = file1 if file1_is_df else pd.read_csv(file1)
    df2 = file2 if file2_is_df else pd.read_csv(file2)

    # Optional ID cleaning
    if clean_key_field_in == 'file1':
        df1[id_field1] = df1[id_field1].apply(clean_custom_id)
    elif clean_key_field_in == 'file2':
        df2[id_field2] = df2[id_field2].apply(clean_custom_id)

    # Apply cleaning to comparison fields BEFORE merge
    df1[field1] = df1[field1].apply(lambda x: strip_commas(x, na_dict=na_dict))
    df2[field2] = df2[field2].apply(lambda x: strip_commas(x, na_dict=na_dict))

    # Rename ID columns for merging
    df1 = df1.rename(columns={id_field1: '__merge_id__'})
    
    df2 = df2.rename(columns={id_field2: '__merge_id__'})
    
    # Merge
    merged = pd.merge(df1, df2, on='__merge_id__', suffixes=('_file1', '_file2'), how='inner')
    print("Merged columns:", merged.columns.tolist())

    # Determine correct column names
    f1_col = f"{field1}_file1" if f"{field1}_file1" in merged.columns else field1
    f2_col = f"{field2}_file2" if f"{field2}_file2" in merged.columns else field2

    if f1_col not in merged.columns:
        raise KeyError(f"'{f1_col}' not found in merged dataframe.")
    if f2_col not in merged.columns:
        raise KeyError(f"'{f2_col}' not found in merged dataframe.")

    # Compare cleaned values directly
    merged['match'] = (
    (merged[f1_col] == merged[f2_col]) |
    (pd.isna(merged[f1_col]) & pd.isna(merged[f2_col]))
)

    
    # Count number of True/False in match column
    print(merged['match'].value_counts())

    return merged[['__merge_id__', f1_col, f2_col, 'match']]




import pandas as pd

def report_mismatches(df,  id_field, model_field, human_field, match_field='match',text=""):
    """
    Prints a statement for each row where match_field == False.

    Parameters:
    - df: pandas DataFrame
    - id_field: column name containing the unique ID
    - model_field: column name for model-returned value
    - human_field: column name for human-coded value
    - match_field: column name for match indicator (default = 'match')
    """
    count = 0
    mismatches = df[df[match_field] == False]  # Filter mismatches
    
    for idx, row in mismatches.iterrows():
        print(f'[{idx}] {text}: "{row[id_field][:14]}" returned "{row[model_field]}", '
          f'but a human coded it as "{row[human_field]}"')

# %%
df1 = pd.read_csv(createdfile)
df2 = pd.read_csv(priorfile)

print("Created file columns:", df1.columns.tolist())
print("Prior file columns:", df2.columns.tolist())

df_comparison = compare_fields(
    file1=createdfile,
    file2=priorfile,
    field1="authorized_common_stock",           # from createdfile
    field2="Number of Common Stocks Issued",           # from priorfile
    id_field1="custom_id",           # ID column in createdfile
    id_field2="File Name",           # ID column in priorfile
    clean_key_field_in="file1",       # clean `custom_id` before merging
    na_dict = {    "Uncertain": np.nan,    "N/A": np.nan,    "": np.nan, "MISSING": np.nan}

)

print(df_comparison.head(10).to_string())
report_mismatches(df_comparison, 
    id_field='__merge_id__',model_field='authorized_common_stock',human_field="Number of Common Stocks Issued", text="Common Stock Issued")
# Out:
# Created file columns: ['custom_id', 'company_name', 'document_title', 'inc_document', 'filing_date', 'state_of_incorporation', 'authorized_common_stock', 'authorized_common_stock_d', 'authorized_preferred_stock', 'authorized_preferred_stock_d', 'preferred_stock_series', 'preferred_stock_series_d', 'total_shares_authorized', 'total_shares_authorized_d', 'multiple_common_stock_classes', 'common_voting_rights', 'common_issued_shares', 'preferred_stock_terms_Series A', 'liq_pref_flag', 'liquidation_priority_order', 'liquidation_priority_order_d', 'conversion_rights', 'conversion_rights_d', 'automatic_conversion_triggers', 'automatic_conversion_triggers_d', 'merger_indicator', 'merger_indicator_d', 'Name_change_flag', 'notable_features_summary', 'preferred_stock_terms', 'preferred_stock_terms_Series B', 'preferred_stock_terms_Series A1', 'preferred_stock_terms_Series B2', 'preferred_stock_terms_Series C', 'preferred_stock_terms_Series A-1', 'preferred_stock_terms_Series A-2', 'preferred_stock_terms_Series Seed', 'preferred_stock_terms_Series B+', 'preferred_stock_terms_Series D', 'preferred_stock_terms_Series E', 'preferred_stock_terms_Series B-1', 'preferred_stock_terms_Series E-1', 'preferred_stock_terms_Series F', 'preferred_stock_terms_Series 1', 'preferred_stock_terms_Series 2', 'preferred_stock_terms_Series 3', 'preferred_stock_terms_Series A-3', 'preferred_stock_terms_Series X', 'preferred_stock_terms_Series AA', 'preferred_stock_terms_Series C-1', 'preferred_stock_terms_Series D-1', 'preferred_stock_terms_Series D-2', 'preferred_stock_terms_Series A2', 'preferred_stock_terms_Series A3', 'preferred_stock_terms_Series S', 'preferred_stock_terms_Series B-2', 'preferred_stock_terms_Series A Convertible Preferred Stock', 'preferred_stock_terms_Series I-A Preferred', 'preferred_stock_terms_Series A Preferred Stock', 'preferred_stock_terms_Series B Preferred Stock', 'preferred_stock_terms_Series C Preferred Stock', 'preferred_stock_terms_Series 1-A Preferred', 'preferred_stock_terms_Series 1-A', 'preferred_stock_terms_Series A Preferred', 'preferred_stock_terms_Series B Preferred', 'preferred_stock_terms_Series C Preferred', "preferred_stock_terms_Series A'", 'preferred_stock_terms_Series B Convertible Preferred Stock', "preferred_stock_terms_Series A-1'", 'preferred_stock_terms_Series AA-1 Convertible Preferred Stock', 'preferred_stock_terms_Series A-1 Convertible Preferred Stock', 'preferred_stock_terms_Series A-4', 'preferred_stock_terms_Series A-5', 'preferred_stock_terms_Series B-2 Convertible Preferred Stock', 'preferred_stock_terms_Series A Redeemable Preferred Stock', 'preferred_stock_terms_Series C Convertible Preferred Stock', 'preferred_stock_terms_Series D Convertible Preferred Stock', 'preferred_stock_terms_Series E Convertible Preferred Stock', 'preferred_stock_terms_Series B-1 Preferred Stock', 'preferred_stock_terms_Series B-2 Preferred Stock', 'preferred_stock_terms_Series A-1 Preferred Stock', 'preferred_stock_terms_Series A_present', 'preferred_stock_terms_Series A_shares_authorized', 'preferred_stock_terms_Series A_liquidation_multiple', 'preferred_stock_terms_Series A_conversion_price', 'preferred_stock_terms_Series A_conversion_price_d', 'preferred_stock_terms_Series A_dividend_rate_annual', 'preferred_stock_terms_Series A_cumulative_dividends', 'preferred_stock_terms_Series A_participation_rights', 'preferred_stock_terms_Series A_dividend_priority_order', 'preferred_stock_terms_Series A_dividend_priority_order_d', 'preferred_stock_terms_Series A_antidilution_protection', 'preferred_stock_terms_Series A_antidilution_type', 'preferred_stock_terms_Series A_antidilution_protection_d', 'preferred_stock_terms_Series A_redemption_rights', 'preferred_stock_terms_Series A_voting_rights', 'preferred_stock_terms_Series A_special_class_protections', 'preferred_stock_terms_Series A_special_class_protections_d', 'preferred_stock_terms_Series A_liquidation_preference.amount', 'preferred_stock_terms_Series A_liquidation_pre ...
# Prior file columns: ['File Name', 'Company Name', 'Document Type', 'Date', 'Liquidation Preference', 'Liquidation Priority Order', 'Participation Cap', 'Number of Common Stocks Issued', 'Number of Preferred Stock Issued', 'Total Number of Stocks Issued', 'Multiple Common Stock Series', 'Conversion Price (Initial)', 'Antidilution', 'Dividends (Type)', 'Participation', 'Redemption', 'Dividend Priority Order', 'Dissolution', 'Notes']
# Merged columns: ['__merge_id__', 'company_name', 'document_title', 'inc_document', 'filing_date', 'state_of_incorporation', 'authorized_common_stock', 'authorized_common_stock_d', 'authorized_preferred_stock', 'authorized_preferred_stock_d', 'preferred_stock_series', 'preferred_stock_series_d', 'total_shares_authorized', 'total_shares_authorized_d', 'multiple_common_stock_classes', 'common_voting_rights', 'common_issued_shares', 'preferred_stock_terms_Series A', 'liq_pref_flag', 'liquidation_priority_order', 'liquidation_priority_order_d', 'conversion_rights', 'conversion_rights_d', 'automatic_conversion_triggers', 'automatic_conversion_triggers_d', 'merger_indicator', 'merger_indicator_d', 'Name_change_flag', 'notable_features_summary', 'preferred_stock_terms', 'preferred_stock_terms_Series B', 'preferred_stock_terms_Series A1', 'preferred_stock_terms_Series B2', 'preferred_stock_terms_Series C', 'preferred_stock_terms_Series A-1', 'preferred_stock_terms_Series A-2', 'preferred_stock_terms_Series Seed', 'preferred_stock_terms_Series B+', 'preferred_stock_terms_Series D', 'preferred_stock_terms_Series E', 'preferred_stock_terms_Series B-1', 'preferred_stock_terms_Series E-1', 'preferred_stock_terms_Series F', 'preferred_stock_terms_Series 1', 'preferred_stock_terms_Series 2', 'preferred_stock_terms_Series 3', 'preferred_stock_terms_Series A-3', 'preferred_stock_terms_Series X', 'preferred_stock_terms_Series AA', 'preferred_stock_terms_Series C-1', 'preferred_stock_terms_Series D-1', 'preferred_stock_terms_Series D-2', 'preferred_stock_terms_Series A2', 'preferred_stock_terms_Series A3', 'preferred_stock_terms_Series S', 'preferred_stock_terms_Series B-2', 'preferred_stock_terms_Series A Convertible Preferred Stock', 'preferred_stock_terms_Series I-A Preferred', 'preferred_stock_terms_Series A Preferred Stock', 'preferred_stock_terms_Series B Preferred Stock', 'preferred_stock_terms_Series C Preferred Stock', 'preferred_stock_terms_Series 1-A Preferred', 'preferred_stock_terms_Series 1-A', 'preferred_stock_terms_Series A Preferred', 'preferred_stock_terms_Series B Preferred', 'preferred_stock_terms_Series C Preferred', "preferred_stock_terms_Series A'", 'preferred_stock_terms_Series B Convertible Preferred Stock', "preferred_stock_terms_Series A-1'", 'preferred_stock_terms_Series AA-1 Convertible Preferred Stock', 'preferred_stock_terms_Series A-1 Convertible Preferred Stock', 'preferred_stock_terms_Series A-4', 'preferred_stock_terms_Series A-5', 'preferred_stock_terms_Series B-2 Convertible Preferred Stock', 'preferred_stock_terms_Series A Redeemable Preferred Stock', 'preferred_stock_terms_Series C Convertible Preferred Stock', 'preferred_stock_terms_Series D Convertible Preferred Stock', 'preferred_stock_terms_Series E Convertible Preferred Stock', 'preferred_stock_terms_Series B-1 Preferred Stock', 'preferred_stock_terms_Series B-2 Preferred Stock', 'preferred_stock_terms_Series A-1 Preferred Stock', 'preferred_stock_terms_Series A_present', 'preferred_stock_terms_Series A_shares_authorized', 'preferred_stock_terms_Series A_liquidation_multiple', 'preferred_stock_terms_Series A_conversion_price', 'preferred_stock_terms_Series A_conversion_price_d', 'preferred_stock_terms_Series A_dividend_rate_annual', 'preferred_stock_terms_Series A_cumulative_dividends', 'preferred_stock_terms_Series A_participation_rights', 'preferred_stock_terms_Series A_dividend_priority_order', 'preferred_stock_terms_Series A_dividend_priority_order_d', 'preferred_stock_terms_Series A_antidilution_protection', 'preferred_stock_terms_Series A_antidilution_type', 'preferred_stock_terms_Series A_antidilution_protection_d', 'preferred_stock_terms_Series A_redemption_rights', 'preferred_stock_terms_Series A_voting_rights', 'preferred_stock_terms_Series A_special_class_protections', 'preferred_stock_terms_Series A_special_class_protections_d', 'preferred_stock_terms_Series A_liquidation_preference.amount', 'preferred_stock_terms_Series A_liquidation_prefer ...
# match
# True     108
# False     38
# Name: count, dtype: int64
#                                    __merge_id__  authorized_common_stock Number of Common Stocks Issued  match
# 0  234_2012-02-14_Certificates of Incorporation               97374073.0                            NaN  False
# 1  234_2010-03-15_Certificates of Incorporation               76000000.0                            NaN  False
# 2  234_2011-03-14_Certificates of Incorporation               91000000.0                            NaN  False
# 3  234_2011-07-25_Certificates of Incorporation               91000000.0                            NaN  False
# 4  234_2006-07-31_Certificates of Incorporation               30000000.0                            NaN  False
# 5  234_2007-03-22_Certificates of Incorporation               30000000.0                            NaN  False
# 6  234_2007-07-13_Certificates of Incorporation               43300000.0                            NaN  False
# 7  234_2008-03-27_Certificates of Incorporation               43300000.0                            NaN  False
# 8  234_2009-10-07_Certificates of Incorporation               43360000.0                            NaN  False
# 9  234_2009-11-18_Certificates of Incorporation               44443165.0                            NaN  False
# [0] Common Stock Issued: "234_2012-02-14" returned "97374073.0", but a human coded it as "nan"
# [1] Common Stock Issued: "234_2010-03-15" returned "76000000.0", but a human coded it as "nan"
# [2] Common Stock Issued: "234_2011-03-14" returned "91000000.0", but a human coded it as "nan"
# [3] Common Stock Issued: "234_2011-07-25" returned "91000000.0", but a human coded it as "nan"
# [4] Common Stock Issued: "234_2006-07-31" returned "30000000.0", but a human coded it as "nan"
# [5] Common Stock Issued: "234_2007-03-22" returned "30000000.0", but a human coded it as "nan"
# [6] Common Stock Issued: "234_2007-07-13" returned "43300000.0", but a human coded it as "nan"
# [7] Common Stock Issued: "234_2008-03-27" returned "43300000.0", but a human coded it as "nan"
# [8] Common Stock Issued: "234_2009-10-07" returned "43360000.0", but a human coded it as "nan"
# [9] Common Stock Issued: "234_2009-11-18" returned "44443165.0", but a human coded it as "nan"
# [12] Common Stock Issued: "234_2006-03-15" returned "10000000.0", but a human coded it as "nan"
# [14] Common Stock Issued: "223_2008-05-29" returned "105500000.0", but a human coded it as "105000000.0"
# [34] Common Stock Issued: "200_2005-10-06" returned "22000000.0", but a human coded it as "nan"
# [35] Common Stock Issued: "200_2006-07-13" returned "22000000.0", but a human coded it as "nan"
# [41] Common Stock Issued: "193_2007-06-11" returned "21000000.0", but a human coded it as "20000000.0"
# [58] Common Stock Issued: "188_2006-06-22" returned "10000000.0", but a human coded it as "20000000.0"
# [60] Common Stock Issued: "188_2009-03-31" returned "nan", but a human coded it as "1699584.0"
# [63] Common Stock Issued: "184_2006-06-13" returned "610000000.0", but a human coded it as "394919462.0"
# [64] Common Stock Issued: "185_2004-03-03" returned "40000000.0", but a human coded it as "1964067.0"
# [69] Common Stock Issued: "181_2007-05-30" returned "25400000.0", but a human coded it as "24000000.0"
# [73] Common Stock Issued: "169_2007-10-15" returned "45000000.0", but a human coded it as "19408086.0"
# [74] Common Stock Issued: "169_2011-08-16" returned "80000000.0", but a human coded it as "$80000000.00"
# [75] Common Stock Issued: "181_2006-02-15" returned "25400000.0", but a human coded it as "24000000.0"
# [80] Common Stock Issued: "168_2007-11-08" returned "50000000.0", but a human coded it as "12000000.0"
# [84] Common Stock Issued: "166_2006-12-21" returned "35000000.0", but a human coded it as "10000000.0"
# [85] Common Stock Issued: "166_2007-12-20" returned "56000000.0", but a human coded it as "95626398.0"
# [87] Common Stock Issued: "166_2009-01-29" returned "71500000.0", but a human coded it as "7150000.0"
# [88] Common Stock Issued: "166_2003-05-21" returned "1000000.0", but a human coded it as "1000.0"
# [91] Common Stock Issued: "166_2005-03-10" returned "7650000.0", but a human coded it as "7650000`"
# [94] Common Stock Issued: "155_2016-09-23" returned "154340685.0", but a human coded it as "154354681.0"
# [97] Common Stock Issued: "155_2016-06-24" returned "108000000.0", but a human coded it as "110000000.0"
# [99] Common Stock Issued: "155_2014-08-29" returned "108000000.0", but a human coded it as "189761284.0"
# [107] Common Stock Issued: "155_2005-04-06" returned "32669092.0", but a human coded it as "32699092.0"
# [110] Common Stock Issued: "155_2002-10-29" returned "15816241.0", but a human coded it as "nan"
# [113] Common Stock Issued: "155_2004-06-24" returned "16849751.0", but a human coded it as "nan"
# [142] Common Stock Issued: "120_2013-04-12" returned "nan", but a human coded it as "20480858.0"
# [144] Common Stock Issued: "104_2006-09-08" returned "145000000.0", but a human coded it as "45000000.0"
# [145] Common Stock Issued: "110_2010-02-09" returned "nan", but a human coded it as "20480858.0"

# %%
df_comparison = compare_fields(
    file1=createdfile,
    file2=priorfile,
    field1="authorized_preferred_stock",           # from createdfile
    field2="Number of Preferred Stock Issued",           # from priorfile
    id_field1="custom_id",           # ID column in createdfile
    id_field2="File Name",       # clean `custom_id` before merging
    clean_key_field_in="file1",       # clean `custom_id` before merging
    na_dict = {    "Uncertain": np.nan,    "N/A": np.nan,    "": np.nan, "MISSING": np.nan}
    
    
    
)

report_mismatches(df_comparison, 
    id_field='__merge_id__',model_field='authorized_preferred_stock',human_field="Number of Preferred Stock Issued")
# Out:
# Merged columns: ['__merge_id__', 'company_name', 'document_title', 'inc_document', 'filing_date', 'state_of_incorporation', 'authorized_common_stock', 'authorized_common_stock_d', 'authorized_preferred_stock', 'authorized_preferred_stock_d', 'preferred_stock_series', 'preferred_stock_series_d', 'total_shares_authorized', 'total_shares_authorized_d', 'multiple_common_stock_classes', 'common_voting_rights', 'common_issued_shares', 'preferred_stock_terms_Series A', 'liq_pref_flag', 'liquidation_priority_order', 'liquidation_priority_order_d', 'conversion_rights', 'conversion_rights_d', 'automatic_conversion_triggers', 'automatic_conversion_triggers_d', 'merger_indicator', 'merger_indicator_d', 'Name_change_flag', 'notable_features_summary', 'preferred_stock_terms', 'preferred_stock_terms_Series B', 'preferred_stock_terms_Series A1', 'preferred_stock_terms_Series B2', 'preferred_stock_terms_Series C', 'preferred_stock_terms_Series A-1', 'preferred_stock_terms_Series A-2', 'preferred_stock_terms_Series Seed', 'preferred_stock_terms_Series B+', 'preferred_stock_terms_Series D', 'preferred_stock_terms_Series E', 'preferred_stock_terms_Series B-1', 'preferred_stock_terms_Series E-1', 'preferred_stock_terms_Series F', 'preferred_stock_terms_Series 1', 'preferred_stock_terms_Series 2', 'preferred_stock_terms_Series 3', 'preferred_stock_terms_Series A-3', 'preferred_stock_terms_Series X', 'preferred_stock_terms_Series AA', 'preferred_stock_terms_Series C-1', 'preferred_stock_terms_Series D-1', 'preferred_stock_terms_Series D-2', 'preferred_stock_terms_Series A2', 'preferred_stock_terms_Series A3', 'preferred_stock_terms_Series S', 'preferred_stock_terms_Series B-2', 'preferred_stock_terms_Series A Convertible Preferred Stock', 'preferred_stock_terms_Series I-A Preferred', 'preferred_stock_terms_Series A Preferred Stock', 'preferred_stock_terms_Series B Preferred Stock', 'preferred_stock_terms_Series C Preferred Stock', 'preferred_stock_terms_Series 1-A Preferred', 'preferred_stock_terms_Series 1-A', 'preferred_stock_terms_Series A Preferred', 'preferred_stock_terms_Series B Preferred', 'preferred_stock_terms_Series C Preferred', "preferred_stock_terms_Series A'", 'preferred_stock_terms_Series B Convertible Preferred Stock', "preferred_stock_terms_Series A-1'", 'preferred_stock_terms_Series AA-1 Convertible Preferred Stock', 'preferred_stock_terms_Series A-1 Convertible Preferred Stock', 'preferred_stock_terms_Series A-4', 'preferred_stock_terms_Series A-5', 'preferred_stock_terms_Series B-2 Convertible Preferred Stock', 'preferred_stock_terms_Series A Redeemable Preferred Stock', 'preferred_stock_terms_Series C Convertible Preferred Stock', 'preferred_stock_terms_Series D Convertible Preferred Stock', 'preferred_stock_terms_Series E Convertible Preferred Stock', 'preferred_stock_terms_Series B-1 Preferred Stock', 'preferred_stock_terms_Series B-2 Preferred Stock', 'preferred_stock_terms_Series A-1 Preferred Stock', 'preferred_stock_terms_Series A_present', 'preferred_stock_terms_Series A_shares_authorized', 'preferred_stock_terms_Series A_liquidation_multiple', 'preferred_stock_terms_Series A_conversion_price', 'preferred_stock_terms_Series A_conversion_price_d', 'preferred_stock_terms_Series A_dividend_rate_annual', 'preferred_stock_terms_Series A_cumulative_dividends', 'preferred_stock_terms_Series A_participation_rights', 'preferred_stock_terms_Series A_dividend_priority_order', 'preferred_stock_terms_Series A_dividend_priority_order_d', 'preferred_stock_terms_Series A_antidilution_protection', 'preferred_stock_terms_Series A_antidilution_type', 'preferred_stock_terms_Series A_antidilution_protection_d', 'preferred_stock_terms_Series A_redemption_rights', 'preferred_stock_terms_Series A_voting_rights', 'preferred_stock_terms_Series A_special_class_protections', 'preferred_stock_terms_Series A_special_class_protections_d', 'preferred_stock_terms_Series A_liquidation_preference.amount', 'preferred_stock_terms_Series A_liquidation_prefer ...
# match
# True     110
# False     36
# Name: count, dtype: int64
# [0] : "234_2012-02-14" returned "66240897.0", but a human coded it as "nan"
# [1] : "234_2010-03-15" returned "52192797.0", but a human coded it as "nan"
# [2] : "234_2011-03-14" returned "66240897.0", but a human coded it as "nan"
# [3] : "234_2011-07-25" returned "66240897.0", but a human coded it as "nan"
# [4] : "234_2006-07-31" returned "14200000.0", but a human coded it as "nan"
# [5] : "234_2007-03-22" returned "14400000.0", but a human coded it as "nan"
# [6] : "234_2007-07-13" returned "26634720.0", but a human coded it as "nan"
# [7] : "234_2008-03-27" returned "26634720.0", but a human coded it as "nan"
# [8] : "234_2009-10-07" returned "26694720.0", but a human coded it as "nan"
# [9] : "234_2009-11-18" returned "26777885.0", but a human coded it as "nan"
# [12] : "234_2006-03-15" returned "nan", but a human coded it as "10000000.0"
# [34] : "200_2005-10-06" returned "9484715.0", but a human coded it as "nan"
# [35] : "200_2006-07-13" returned "9711713.0", but a human coded it as "nan"
# [63] : "184_2006-06-13" returned "394919462.0", but a human coded it as "215080538.0"
# [64] : "185_2004-03-03" returned "20000000.0", but a human coded it as "3000000.0"
# [67] : "183_2008-09-24" returned "21500000.0", but a human coded it as "20000000.0"
# [68] : "183_2008-11-20" returned "21500000.0", but a human coded it as "20000000.0"
# [72] : "181_2011-01-18" returned "nan", but a human coded it as "0.0"
# [73] : "169_2007-10-15" returned "19408086.0", but a human coded it as "45000000.0"
# [74] : "169_2011-08-16" returned "42129034.0", but a human coded it as "42189034.0"
# [84] : "166_2006-12-21" returned "27000000.0", but a human coded it as "1000000.0"
# [88] : "166_2003-05-21" returned "nan", but a human coded it as "0.0"
# [93] : "155_2016-08-10" returned "82175278.0", but a human coded it as "91175278.0"
# [94] : "155_2016-09-23" returned "124204823.0", but a human coded it as "73923823.0"
# [95] : "157_2004-04-14" returned "8850000.0", but a human coded it as "8.85"
# [96] : "155_2016-03-18" returned "82175278.0", but a human coded it as "76275072.0"
# [97] : "155_2016-06-24" returned "82175278.0", but a human coded it as "82175000.0"
# [110] : "155_2002-10-29" returned "10126241.0", but a human coded it as "nan"
# [113] : "155_2004-06-24" returned "11159751.0", but a human coded it as "nan"
# [121] : "148_2004-03-03" returned "nan", but a human coded it as "0.0"
# [125] : "136_2007-02-14" returned "13337963.0", but a human coded it as "33337963.0"
# [130] : "131_2005-04-06" returned "2727272.0", but a human coded it as "2272272.0"
# [131] : "132_2000-01-10" returned "nan", but a human coded it as "0.0"
# [136] : "130_2007-12-17" returned "40400000.0", but a human coded it as "40300000.0"
# [137] : "131_2004-10-12" returned "2727272.0", but a human coded it as "2272272.0"
# [145] : "110_2010-02-09" returned "nan", but a human coded it as "18428798.0"

# %%
df_comparison = compare_fields(
    file1=createdfile,
    file2=priorfile,
    field1="total_shares_authorized",           # from createdfile
    field2="Total Number of Stocks Issued",           # from priorfile
    id_field1="custom_id",           # ID column in createdfile
    id_field2="File Name",           # ID column in priorfile
    clean_key_field_in="file1",       # clean `custom_id` before merging
    na_dict = {    "Uncertain": 0.0,    "N/A": np.nan,    "": np.nan, "MISSING": np.nan}    
)



report_mismatches(df_comparison, 
    id_field='__merge_id__',model_field='total_shares_authorized',human_field="Total Number of Stocks Issued")
# Out:
# Merged columns: ['__merge_id__', 'company_name', 'document_title', 'inc_document', 'filing_date', 'state_of_incorporation', 'authorized_common_stock', 'authorized_common_stock_d', 'authorized_preferred_stock', 'authorized_preferred_stock_d', 'preferred_stock_series', 'preferred_stock_series_d', 'total_shares_authorized', 'total_shares_authorized_d', 'multiple_common_stock_classes', 'common_voting_rights', 'common_issued_shares', 'preferred_stock_terms_Series A', 'liq_pref_flag', 'liquidation_priority_order', 'liquidation_priority_order_d', 'conversion_rights', 'conversion_rights_d', 'automatic_conversion_triggers', 'automatic_conversion_triggers_d', 'merger_indicator', 'merger_indicator_d', 'Name_change_flag', 'notable_features_summary', 'preferred_stock_terms', 'preferred_stock_terms_Series B', 'preferred_stock_terms_Series A1', 'preferred_stock_terms_Series B2', 'preferred_stock_terms_Series C', 'preferred_stock_terms_Series A-1', 'preferred_stock_terms_Series A-2', 'preferred_stock_terms_Series Seed', 'preferred_stock_terms_Series B+', 'preferred_stock_terms_Series D', 'preferred_stock_terms_Series E', 'preferred_stock_terms_Series B-1', 'preferred_stock_terms_Series E-1', 'preferred_stock_terms_Series F', 'preferred_stock_terms_Series 1', 'preferred_stock_terms_Series 2', 'preferred_stock_terms_Series 3', 'preferred_stock_terms_Series A-3', 'preferred_stock_terms_Series X', 'preferred_stock_terms_Series AA', 'preferred_stock_terms_Series C-1', 'preferred_stock_terms_Series D-1', 'preferred_stock_terms_Series D-2', 'preferred_stock_terms_Series A2', 'preferred_stock_terms_Series A3', 'preferred_stock_terms_Series S', 'preferred_stock_terms_Series B-2', 'preferred_stock_terms_Series A Convertible Preferred Stock', 'preferred_stock_terms_Series I-A Preferred', 'preferred_stock_terms_Series A Preferred Stock', 'preferred_stock_terms_Series B Preferred Stock', 'preferred_stock_terms_Series C Preferred Stock', 'preferred_stock_terms_Series 1-A Preferred', 'preferred_stock_terms_Series 1-A', 'preferred_stock_terms_Series A Preferred', 'preferred_stock_terms_Series B Preferred', 'preferred_stock_terms_Series C Preferred', "preferred_stock_terms_Series A'", 'preferred_stock_terms_Series B Convertible Preferred Stock', "preferred_stock_terms_Series A-1'", 'preferred_stock_terms_Series AA-1 Convertible Preferred Stock', 'preferred_stock_terms_Series A-1 Convertible Preferred Stock', 'preferred_stock_terms_Series A-4', 'preferred_stock_terms_Series A-5', 'preferred_stock_terms_Series B-2 Convertible Preferred Stock', 'preferred_stock_terms_Series A Redeemable Preferred Stock', 'preferred_stock_terms_Series C Convertible Preferred Stock', 'preferred_stock_terms_Series D Convertible Preferred Stock', 'preferred_stock_terms_Series E Convertible Preferred Stock', 'preferred_stock_terms_Series B-1 Preferred Stock', 'preferred_stock_terms_Series B-2 Preferred Stock', 'preferred_stock_terms_Series A-1 Preferred Stock', 'preferred_stock_terms_Series A_present', 'preferred_stock_terms_Series A_shares_authorized', 'preferred_stock_terms_Series A_liquidation_multiple', 'preferred_stock_terms_Series A_conversion_price', 'preferred_stock_terms_Series A_conversion_price_d', 'preferred_stock_terms_Series A_dividend_rate_annual', 'preferred_stock_terms_Series A_cumulative_dividends', 'preferred_stock_terms_Series A_participation_rights', 'preferred_stock_terms_Series A_dividend_priority_order', 'preferred_stock_terms_Series A_dividend_priority_order_d', 'preferred_stock_terms_Series A_antidilution_protection', 'preferred_stock_terms_Series A_antidilution_type', 'preferred_stock_terms_Series A_antidilution_protection_d', 'preferred_stock_terms_Series A_redemption_rights', 'preferred_stock_terms_Series A_voting_rights', 'preferred_stock_terms_Series A_special_class_protections', 'preferred_stock_terms_Series A_special_class_protections_d', 'preferred_stock_terms_Series A_liquidation_preference.amount', 'preferred_stock_terms_Series A_liquidation_prefer ...
# match
# True     99
# False    47
# Name: count, dtype: int64
# [0] : "234_2012-02-14" returned "163614970.0", but a human coded it as "nan"
# [1] : "234_2010-03-15" returned "128192797.0", but a human coded it as "nan"
# [2] : "234_2011-03-14" returned "157240897.0", but a human coded it as "nan"
# [3] : "234_2011-07-25" returned "157240897.0", but a human coded it as "nan"
# [4] : "234_2006-07-31" returned "44200000.0", but a human coded it as "nan"
# [5] : "234_2007-03-22" returned "44400000.0", but a human coded it as "nan"
# [6] : "234_2007-07-13" returned "69934720.0", but a human coded it as "nan"
# [7] : "234_2008-03-27" returned "69934720.0", but a human coded it as "nan"
# [8] : "234_2009-10-07" returned "70054720.0", but a human coded it as "nan"
# [9] : "234_2009-11-18" returned "71221050.0", but a human coded it as "nan"
# [12] : "234_2006-03-15" returned "10000000.0", but a human coded it as "nan"
# [14] : "223_2008-05-29" returned "165886020.0", but a human coded it as "165386020.0"
# [34] : "200_2005-10-06" returned "31484715.0", but a human coded it as "nan"
# [35] : "200_2006-07-13" returned "31711713.0", but a human coded it as "nan"
# [39] : "200_2005-09-01" returned "16000000.0", but a human coded it as "nan"
# [41] : "193_2007-06-11" returned "32500000.0", but a human coded it as "31500000.0"
# [58] : "188_2006-06-22" returned "20000000.0", but a human coded it as "30000000.0"
# [60] : "188_2009-03-31" returned "nan", but a human coded it as "4999584.0"
# [63] : "184_2006-06-13" returned "1004919462.0", but a human coded it as "610000000.0"
# [64] : "185_2004-03-03" returned "60000000.0", but a human coded it as "4964067.0"
# [67] : "183_2008-09-24" returned "66500000.0", but a human coded it as "65000000.0"
# [68] : "183_2008-11-20" returned "66500000.0", but a human coded it as "65000000.0"
# [74] : "169_2011-08-16" returned "122129034.0", but a human coded it as "122129084.0"
# [78] : "166_2015-03-12" returned "272519868.0", but a human coded it as "nan"
# [84] : "166_2006-12-21" returned "62000000.0", but a human coded it as "11000000.0"
# [85] : "166_2007-12-20" returned "95626398.0", but a human coded it as "135252796.0"
# [87] : "166_2009-01-29" returned "126567758.0", but a human coded it as "62217758.0"
# [88] : "166_2003-05-21" returned "1000000.0", but a human coded it as "1000.0"
# [93] : "155_2016-08-10" returned "190175278.0", but a human coded it as "199175278.0"
# [94] : "155_2016-09-23" returned "278545508.0", but a human coded it as "228278504.0"
# [96] : "155_2016-03-18" returned "190175278.0", but a human coded it as "184275072.0"
# [97] : "155_2016-06-24" returned "190175278.0", but a human coded it as "192175000.0"
# [99] : "155_2014-08-29" returned "189761284.0", but a human coded it as "271522568.0"
# [110] : "155_2002-10-29" returned "25942482.0", but a human coded it as "nan"
# [111] : "155_2003-07-16" returned "25953482.0", but a human coded it as "25925482.0"
# [112] : "155_2004-03-29" returned "26549226.0", but a human coded it as "nan"
# [113] : "155_2004-06-24" returned "28009502.0", but a human coded it as "nan"
# [114] : "148_2005-07-22" returned "1699189.0", but a human coded it as "1689189.0"
# [119] : "145_2007-08-07" returned "259484518.0", but a human coded it as "295484518.0"
# [124] : "135_2011-02-16" returned "244500000.0", but a human coded it as "$244500000.00"
# [125] : "136_2007-02-14" returned "33337963.0", but a human coded it as "53337963.0"
# [130] : "131_2005-04-06" returned "22727272.0", but a human coded it as "22272272.0"
# [133] : "132_2012-04-18" returned "5000.0", but a human coded it as "nan"
# [137] : "131_2004-10-12" returned "22727272.0", but a human coded it as "22272272.0"
# [142] : "120_2013-04-12" returned "nan", but a human coded it as "20480858.0"
# [144] : "104_2006-09-08" returned "238798806.0", but a human coded it as "138798806.0"
# [145] : "110_2010-02-09" returned "nan", but a human coded it as "48295363.0"
