# %%
import os
import json
import pandas as pd
from pathlib import Path
from tqdm import tqdm

# === Settings ===
input_dir = Path(r"D:\vc-research\vc-research\Reese's contributions\reese data\downloaded_batches")

output_csv = input_dir / "combined_extracted_data.csv"

# === Collect flattened results ===
records = []

# === Iterate through all JSONL files ===
for file in tqdm(input_dir.glob("*.jsonl"), desc="Processing JSONL files"):
    with open(file, "r", encoding="utf-8") as f:
        for line in f:
            try:
                row = json.loads(line)
                content_str = row['response']['body']['choices'][0]['message']['content']
                content_dict = json.loads(content_str)

                flat_record = {"custom_id": row.get("custom_id", "")}

                for k, v in content_dict.items():
                    if k == "preferred_stock_terms":
                        if isinstance(v, dict):
                            # Flatten preferred_stock_terms dict into prefixed keys
                            for sub_k, sub_v in v.items():
                                # Clean sub_k: strip hyphens, remove "stock" or "preferred"
                                clean_sub_k = (
                                    sub_k.replace("-", "")  # remove hyphens
                                         .replace("Stock", "")  # remove Stock (case-sensitive)
                                         .replace("Preferred", "")
                                         .replace("Convertible","")# remove Preferred (case-sensitive)
                                         .strip()  # remove trailing/leading spaces
                                )
                                flat_record[f"preferred_stock_terms_{clean_sub_k}"] = sub_v
                                
                        else:
                            flat_record["preferred_stock_terms"] = v
                    elif not isinstance(v, dict):
                        flat_record[k] = v

                records.append(flat_record)

            except Exception as e:
                print(f"Error in {file.name}: {e}")

# === Save to CSV ===
df = pd.DataFrame(records)

df.to_csv(output_csv, encoding='utf-8', index=False)
print(f"Saved CSV to: {output_csv}")
# Out:
# Processing JSONL files: 1147it [00:15, 69.55it/s]
# Error in batch_430_G3_out.jsonl: Unterminated string starting at: line 51 column 38 (char 3529)
# Processing JSONL files: 7853it [01:47, 73.21it/s]
# Saved CSV to: D:\vc-research\vc-research\Reese's contributions\reese data\downloaded_batches\combined_extracted_data.csv

# %%
import json
import pandas as pd
from pandas import json_normalize

def expand_all_preferred_stock_columns(df):
    target_cols = [col for col in df.columns if col.startswith("preferred_stock_terms_")]

    def try_parse_json(x):
        if isinstance(x, dict):
            return x
        if isinstance(x, str):
            try:
                return json.loads(x.replace("'", '"'))
            except (json.JSONDecodeError, TypeError):
                return {}
        return {}

    for col in target_cols:
        presence_col = f"{col}_present"
        print(presence_col)

        df[presence_col] = df[col].apply(
            lambda x: bool(x) and str(x).strip().lower() != "nan"
        )

        parsed_series = df.loc[df[presence_col], col].apply(try_parse_json)
        parsed_dicts = parsed_series.tolist()

        # if nothing valid, skip
        if not parsed_dicts:
            continue

        flat_df = json_normalize(parsed_dicts)
        flat_df.columns = [f"{col}_{c}" for c in flat_df.columns]
        flat_df.index = parsed_series.index

        df = pd.concat([df, flat_df], axis=1)

    return df

# %%
df = expand_all_preferred_stock_columns(df)

output_csv = input_dir / "combined_extracted_dataAICoded.csv"
df.to_csv(output_csv, index=False)
print(f"Saved CSV to: {output_csv}")
# Out:
# preferred_stock_terms_Series 1A_present
# preferred_stock_terms_Series 1B_present
# preferred_stock_terms_Series 2A_present
# preferred_stock_terms_Series 2B_present
# preferred_stock_terms_Series 3_present
# preferred_stock_terms_Series 4_present
# preferred_stock_terms_Series A_present
# preferred_stock_terms_Series B_present
# preferred_stock_terms_Series C_present
# preferred_stock_terms_Series 1_present
# preferred_stock_terms_Series 2_present
# preferred_stock_terms_Series D_present
# preferred_stock_terms_Series A1_present
# preferred_stock_terms_Series A2_present
# preferred_stock_terms_Series A3_present
# preferred_stock_terms_Series C1_present
# preferred_stock_terms_Series AA_present
# preferred_stock_terms_Series A1A_present
# preferred_stock_terms_Series 1 Senior_present
# preferred_stock_terms_Series B2_present
# preferred_stock_terms_Series B1_present
# preferred_stock_terms_Series B3_present
# preferred_stock_terms_Series CPrime_present
# preferred_stock_terms_Series AA1_present
# preferred_stock_terms_Series AA2_present
# preferred_stock_terms_Series AA3_present
# preferred_stock_terms_Series BB1_present
# preferred_stock_terms_Series BB2_present
# preferred_stock_terms_Series CC1_present
# preferred_stock_terms_Series BB_present
# preferred_stock_terms_Series I_present
# preferred_stock_terms_Series E_present
# preferred_stock_terms_Series E1_present
# preferred_stock_terms_Series M_present
# preferred_stock_terms_Seed_present
# preferred_stock_terms_Junior_present
# preferred_stock_terms_Series X_present
# preferred_stock_terms_Series II_present
# preferred_stock_terms_Series III_present
# preferred_stock_terms_Series A'_present
# preferred_stock_terms_Series D1_present
# preferred_stock_terms_Series D2_present
# preferred_stock_terms_Series C2_present
# preferred_stock_terms_Series Seed_present
# preferred_stock_terms_Series B+_present
# preferred_stock_terms_Series F_present
# preferred_stock_terms_Series S_present
# preferred_stock_terms_Series IA_present
# preferred_stock_terms_Series A1'_present
# preferred_stock_terms_Series A4_present
# preferred_stock_terms_Series A5_present
# preferred_stock_terms_Series A Redeemable_present
# preferred_stock_terms_Series C Junior_present
# preferred_stock_terms_Class Z_present
# preferred_stock_terms_Preference Shares_present
# preferred_stock_terms_Series C2A_present
# preferred_stock_terms_Series FF_present
# preferred_stock_terms_Series G2_present
# preferred_stock_terms_Series CC_present
# preferred_stock_terms_Series CCI_present
# preferred_stock_terms_Sced1_present
# preferred_stock_terms_Seed2_present
# preferred_stock_terms_Seed1_present
# preferred_stock_terms_Series Z_present
# preferred_stock_terms_Series AO_present
# preferred_stock_terms_Series C3_present
# preferred_stock_terms_Series A0_present
# preferred_stock_terms_Series 2001_present
# preferred_stock_terms_Series 2002_present
# preferred_stock_terms_Series 2006_present
# preferred_stock_terms_New Series A_present
# preferred_stock_terms_Series F1_present
# preferred_stock_terms_Series DD_present
# preferred_stock_terms_Series_present
# preferred_stock_terms_Series B'_present
# preferred_stock_terms_Series D3_present
# preferred_stock_terms_Series A Prime_present
# preferred_stock_terms_Series G_present
# preferred_stock_terms_Series Al_present
# preferred_stock_terms_Series A1(A)_present
# preferred_stock_terms_Series A1(T)_present
# preferred_stock_terms_Class B_present
# preferred_stock_terms_Class C_present
# preferred_stock_terms_Class D_present
# preferred_stock_terms_Class E_present
# preferred_stock_terms_Series IV_present
# preferred_stock_terms_Series 1AB_present
# preferred_stock_terms_Series Seed 2_present
# preferred_stock_terms_Series One_present
# preferred_stock_terms__present
# preferred_stock_terms_Redeemable_present
# preferred_stock_terms_Series E2_present
# preferred_stock_terms_Series A Junior_present
# preferred_stock_terms_Series AB1_present
# preferred_stock_terms_Series AB_present
# preferred_stock_terms_Series AC_present
# preferred_stock_terms_Series G1_present
# preferred_stock_terms_Series G3_present
# preferred_stock_terms_Series G4_present
# preferred_stock_terms_Series G5_present
# preferred_stock_terms_Series G6_present
# preferred_stock_terms_Series AJ_present
# preferred_stock_terms_Series A Prime1_present
# preferred_stock_terms_Series A Prime3_present
# preferred_stock_terms_Series AI_present
# preferred_stock_terms_Series AII_present
# preferred_stock_terms_Series A Prime2_present
# preferred_stock_terms_Series B4_present
# preferred_stock_terms_Seed3_present
# preferred_stock_terms_Founder_present
# preferred_stock_terms_Series B Junior_present
# preferred_stock_terms_Series A3X_present
# preferred_stock_terms_Series XX_present
# preferred_stock_terms_Series Two_present
# preferred_stock_terms_Series Three_present
# preferred_stock_terms_Series A21_present
# preferred_stock_terms_Series H_present
# preferred_stock_terms_Series DI_present
# preferred_stock_terms_Series B/P_present
# preferred_stock_terms_Series BB3_present
# preferred_stock_terms_Series EE_present
# preferred_stock_terms_Series B2a_present
# preferred_stock_terms_Series CNV_present
# preferred_stock_terms_Series B11_present
# preferred_stock_terms_Series B21_present
# preferred_stock_terms_Series 11_present
# preferred_stock_terms_Series BBB_present
# preferred_stock_terms_Series BBB1_present
# preferred_stock_terms_Series BBB2_present
# preferred_stock_terms_Series AAA_present
# preferred_stock_terms_Series Alpha_present
# preferred_stock_terms_Series H1_present
# preferred_stock_terms_Series H2_present
# preferred_stock_terms_Series I1_present
# preferred_stock_terms_Series I2_present
# preferred_stock_terms_Series LI_present
# preferred_stock_terms_Series |_present
# preferred_stock_terms_New Series B_present
# preferred_stock_terms_Series F2_present
# preferred_stock_terms_Series J_present
# preferred_stock_terms_SAFE_present
# preferred_stock_terms_Series 5_present
# preferred_stock_terms_Series 6_present
# preferred_stock_terms_Scrips B_present
# preferred_stock_terms_Series TD_present
# preferred_stock_terms_Series CC2_present
# preferred_stock_terms_Series C22_present
# preferred_stock_terms_Series C4_present
# preferred_stock_terms_Senior Series A_present
# preferred_stock_terms_Junior Series A1_present
# preferred_stock_terms_Junior Series A2_present
# preferred_stock_terms_Series 2005_present
# preferred_stock_terms_Series 2011_present
# preferred_stock_terms_Junior Seed_present
# preferred_stock_terms_Series Z2_present
# preferred_stock_terms_Series Z1_present
# preferred_stock_terms_Series A  , Class 1_present
# preferred_stock_terms_Class 1_present
# preferred_stock_terms_Senior_present
# preferred_stock_terms_FF_present
# preferred_stock_terms_Series Ib_present
# preferred_stock_terms_Series C1A_present
# preferred_stock_terms_Series 1D_present
# preferred_stock_terms_Special Series C2 Voting_present
# preferred_stock_terms_Series AAI_present
# preferred_stock_terms_Series BBI_present
# preferred_stock_terms_Series A*_present
# preferred_stock_terms_Series B*_present
# preferred_stock_terms_Series A, Class I_present
# preferred_stock_terms_Series A, Class II_present
# preferred_stock_terms_Series A, Class III_present
# preferred_stock_terms_Series A, Class IV_present
# preferred_stock_terms_Series 3A_present
# preferred_stock_terms_Series 3B_present
# preferred_stock_terms_Class A1_present
# preferred_stock_terms_Series A11_present
# preferred_stock_terms_SC_present
# preferred_stock_terms_New Series A1_present
# preferred_stock_terms_A_present
# preferred_stock_terms_Mount Hood_present
# preferred_stock_terms_Series Hl_present
# preferred_stock_terms_Series IT_present
# preferred_stock_terms_Nonvoting Junior_present
# preferred_stock_terms_Seed Series_present
# preferred_stock_terms_Old Series A_present
# preferred_stock_terms_Series A  Voting_present
# preferred_stock_terms_Junior Series A_present
# preferred_stock_terms_FP_present
# preferred_stock_terms_12% Note Default_present
# preferred_stock_terms_Series SeedI_present
# preferred_stock_terms_Series Seed2_present
# preferred_stock_terms_Series Seed1_present
# preferred_stock_terms_Series Seed3_present
# preferred_stock_terms_Series Seed4_present
# preferred_stock_terms_Founders_present
# preferred_stock_terms_Series Seed II_present
# preferred_stock_terms_Series S1_present
# preferred_stock_terms_Series S2_present
# preferred_stock_terms_Series A Senior_present
# preferred_stock_terms_Series A1 NV_present
# preferred_stock_terms_Series A4(a)_present
# preferred_stock_terms_Series A4(b)_present
# preferred_stock_terms_Series Scale_present
# preferred_stock_terms_Series SeedNV_present
# preferred_stock_terms_Series A5B_present
# preferred_stock_terms_Seed Series 1_present
# preferred_stock_terms_Seed Series 2A_present
# preferred_stock_terms_Seed Series 2B_present
# preferred_stock_terms_Seed Series 2C_present
# preferred_stock_terms_Series V_present
# preferred_stock_terms_Series A+_present
# preferred_stock_terms_Series F Founders_present
# preferred_stock_terms_Series XY_present
# preferred_stock_terms_Series E3_present
# preferred_stock_terms_Series BI_present
# preferred_stock_terms_Series Seed 1_present
# preferred_stock_terms_Sense Seed_present
# preferred_stock_terms_Series Safe A1_present
# preferred_stock_terms_Series Safe A2_present
# preferred_stock_terms_Series Safe A3_present
# preferred_stock_terms_Series BR_present
# preferred_stock_terms_Series A1S_present
# preferred_stock_terms_Class A_present
# preferred_stock_terms_Initial_present
# preferred_stock_terms_Series SAFE_present
# preferred_stock_terms_Seed B_present
# preferred_stock_terms_Class B1_present
# preferred_stock_terms_Class B2_present
# preferred_stock_terms_Class A2_present
# preferred_stock_terms_Seed Round_present
# preferred_stock_terms_Seed Series2_present
# preferred_stock_terms_Seed C_present
# preferred_stock_terms_Series Seed 3_present
# preferred_stock_terms_Series Seed 1(a)_present
# preferred_stock_terms_Series Seed 1(b)_present
# preferred_stock_terms_Series 1(b)_present
# preferred_stock_terms_Series A6_present
# preferred_stock_terms_Series A7_present
# preferred_stock_terms_Series P_present
# preferred_stock_terms_Series SEED_present
# preferred_stock_terms_Series Bridge_present
# preferred_stock_terms_Series Seed I_present
# preferred_stock_terms_Series B5_present
# preferred_stock_terms_Series SeedII_present
# preferred_stock_terms_Series SeedIII_present
# preferred_stock_terms_FF1_present
# preferred_stock_terms_FF2_present
# preferred_stock_terms_Series EB5_present
# preferred_stock_terms_Junior1_present
# preferred_stock_terms_S2_present
# preferred_stock_terms_TF_present
# preferred_stock_terms_Series A2(a)_present
# preferred_stock_terms_Series A3(a)_present
# preferred_stock_terms_Series A4(c)_present
# preferred_stock_terms_Series AlJ_present
# preferred_stock_terms_Class I_present
# preferred_stock_terms_Series A Plus_present
# preferred_stock_terms_BN_present
# preferred_stock_terms_Founding_present
# preferred_stock_terms_Series At_present
# preferred_stock_terms_Series C NonVoting_present
# preferred_stock_terms_Series Seed Plus_present
# preferred_stock_terms_Series SAFE1_present
# preferred_stock_terms_SAFE1_present
# preferred_stock_terms_Seed Plus_present
# preferred_stock_terms_Series A8_present
# preferred_stock_terms_Junior 1_present
# preferred_stock_terms_Junior 2_present
# preferred_stock_terms_MISSING_present
# preferred_stock_terms_Series Seed 2A_present
# preferred_stock_terms_Series Seed 2B_present
# preferred_stock_terms_Seed 2A_present
# preferred_stock_terms_Seed 2B_present
# preferred_stock_terms_Series SAFE2_present
# preferred_stock_terms_Series FP_present
# preferred_stock_terms_Series X Junior_present
# preferred_stock_terms_Voting Series A_present
# preferred_stock_terms_Series D4_present
# preferred_stock_terms_Series D5_present
# preferred_stock_terms_Series APlus_present
# preferred_stock_terms_Series A1 Prime_present
# preferred_stock_terms_Series A2 Prime_present
# preferred_stock_terms_Series Seed Prime_present
# preferred_stock_terms_Series B1A_present
# preferred_stock_terms_Series B1B_present
# preferred_stock_terms_Seed1 Series_present
# preferred_stock_terms_Seed2 Series_present
# preferred_stock_terms_SeedI Series_present
# preferred_stock_terms_Series CRM_present
# preferred_stock_terms_Series R_present
# preferred_stock_terms_Series AX_present
# preferred_stock_terms_Series B NonVoting_present
# preferred_stock_terms_Series JP_present
# preferred_stock_terms_Series JP1_present
# preferred_stock_terms_Series JP2_present
# preferred_stock_terms_Series Founders_present
# preferred_stock_terms_Series EE1_present
# preferred_stock_terms_Junior A_present
# preferred_stock_terms_Junior A1_present
# preferred_stock_terms_Junior B_present
# preferred_stock_terms_Series Growth_present
# preferred_stock_terms_Series MIT1_present
# preferred_stock_terms_Series MIT2_present
# preferred_stock_terms_Series CN_present
# preferred_stock_terms_Series B Prime_present
# preferred_stock_terms_Series Seed Extension_present
# preferred_stock_terms_Series A Voting_present
# preferred_stock_terms_Series A NonVoting_present
# preferred_stock_terms_Series O Junior_present
# preferred_stock_terms_Series 2010_present
# preferred_stock_terms_Special Voting Series A_present
# preferred_stock_terms_Special Voting Series B_present
# preferred_stock_terms_Series 21_present
# preferred_stock_terms_Series 22_present
# preferred_stock_terms_Series PreA_present
# preferred_stock_terms_Seed 1_present
# preferred_stock_terms_Seed 2_present
# preferred_stock_terms_Non_present
# preferred_stock_terms_Series 4A_present
# preferred_stock_terms_Series NC_present
# preferred_stock_terms_Series 2006A_present
# preferred_stock_terms_Series AAl_present
# preferred_stock_terms_Series IB_present
# preferred_stock_terms_Seed Investment_present
# preferred_stock_terms_Series Y_present
# preferred_stock_terms_Series Seed A_present
# preferred_stock_terms_Special Series_present
# preferred_stock_terms_Series SeedHII_present
# preferred_stock_terms_Series $_present
# preferred_stock_terms_Series A4A3_present
# preferred_stock_terms_Series Seed Plus1_present
# preferred_stock_terms_Series Seed1 Plus_present
# preferred_stock_terms_Series PreSeed_present
# preferred_stock_terms_Safe Series_present
# preferred_stock_terms_Series NV A1_present
# preferred_stock_terms_Series NV A2_present
# preferred_stock_terms_Series SP_present
# preferred_stock_terms_Series Angel_present
# preferred_stock_terms_Series Seed HT_present
# preferred_stock_terms_Series Post Seed_present
# preferred_stock_terms_Series A Nonvoting_present
# preferred_stock_terms_Series PreSeed1_present
# preferred_stock_terms_Series PreSeed2_present
# preferred_stock_terms_Series PreSeed3_present
# preferred_stock_terms_Inception_present
# preferred_stock_terms_Series SeedPlus1_present
# preferred_stock_terms_Series SeedPlus2_present
# preferred_stock_terms_Series B Voting_present
# preferred_stock_terms_Series Seed5_present
# preferred_stock_terms_Series Seed6_present
# preferred_stock_terms_Series Seed7_present
# preferred_stock_terms_Series Founding_present
# preferred_stock_terms_Series Seed PreSeed_present
# preferred_stock_terms_Series Seed B_present
# preferred_stock_terms_Voting Series B_present
# preferred_stock_terms_Nonvoting Series B_present
# preferred_stock_terms_Series ALH Special_present
# preferred_stock_terms_Series Junior 1_present
# preferred_stock_terms_PreSeries A_present
# preferred_stock_terms_pressed1_present
# preferred_stock_terms_pressed2_present
# preferred_stock_terms_Series SeedA_present
# preferred_stock_terms_Series FF1_present
# preferred_stock_terms_Series A 1_present
# preferred_stock_terms_Series Seed0_present
# preferred_stock_terms_Series Seed2 I_present
# preferred_stock_terms_Series Seed2 II_present
# preferred_stock_terms_Seed  Shares_present
# preferred_stock_terms_Series Founder_present
# preferred_stock_terms_Series Seed2A_present
# preferred_stock_terms_Series Seed2B_present
# preferred_stock_terms_Reserve_present
# preferred_stock_terms_Series 1.0_present
# preferred_stock_terms_Series 1.1_present
# preferred_stock_terms_Series 1.2_present
# preferred_stock_terms_Angel_present
# preferred_stock_terms_Series Safe1_present
# preferred_stock_terms_Series Safe2_present
# preferred_stock_terms_Series FP1_present
# preferred_stock_terms_Series D NonVoting_present
# preferred_stock_terms_Seed 3_present
# preferred_stock_terms_Seed 4_present
# preferred_stock_terms_Series Seed1A_present
# preferred_stock_terms_Series A22_present
# preferred_stock_terms_JL_present
# preferred_stock_terms_Series Seed+_present
# preferred_stock_terms_Series Power Seed_present
# preferred_stock_terms_Series Seed |_present
# preferred_stock_terms_Series Safe_present
# preferred_stock_terms_Series Seed 4_present
# preferred_stock_terms_Series Seeda_present
# preferred_stock_terms_NonVoting Series A_present
# preferred_stock_terms_Voting Series B1_present
# preferred_stock_terms_NonVoting Series B1_present
# preferred_stock_terms_Voting Series B2_present
# preferred_stock_terms_NonVoting Series B2_present
# preferred_stock_terms_Series A|_present
# preferred_stock_terms_Series 4B_present
# preferred_stock_terms_Series 4C_present
# preferred_stock_terms_Series 4D_present
# preferred_stock_terms_Series Seed Strategic_present
# preferred_stock_terms_Series 0_present
# preferred_stock_terms_Series SeedPlus_present
# preferred_stock_terms_Series Seed III_present
# preferred_stock_terms_Series Seed HI_present
# preferred_stock_terms_Series Seed IT_present
# preferred_stock_terms_Series Seed H_present
# preferred_stock_terms_Series SeedPrime_present
# preferred_stock_terms_Founder Series_present
# preferred_stock_terms_Series AIII_present
# preferred_stock_terms_PreSeries A1_present
# preferred_stock_terms_Senior  A1_present
# preferred_stock_terms_Series DX_present
# preferred_stock_terms_Series DDX_present
# preferred_stock_terms_Subordinated_present
# preferred_stock_terms_Series1_present
# preferred_stock_terms_Scrips A_present
# preferred_stock_terms_Series BRedemption_present
# preferred_stock_terms_Series 2 Junior_present
# preferred_stock_terms_Series 7_present
# preferred_stock_terms_Series P1_present
# preferred_stock_terms_Series P2_present
# preferred_stock_terms_Series P3_present
# preferred_stock_terms_Series J1_present
# preferred_stock_terms_Series J2_present
# preferred_stock_terms_Series L_present
# preferred_stock_terms_Series Exchange_present
# preferred_stock_terms_Series 1 Seed_present
# preferred_stock_terms_Series 2 Seed_present
# preferred_stock_terms_First Issued_present
# preferred_stock_terms_Series A3 Prime_present
# preferred_stock_terms_Series 1NV_present
# preferred_stock_terms_Series D Prime_present
# preferred_stock_terms_Series AZ_present
# preferred_stock_terms_Series T_present
# preferred_stock_terms_Series E4_present
# preferred_stock_terms_Series D2A_present
# preferred_stock_terms_Series E5_present
# preferred_stock_terms_Series 1C_present
# preferred_stock_terms_Series 1E_present
# preferred_stock_terms_Series 1F_present
# preferred_stock_terms_Series C2B_present
# preferred_stock_terms_Series C*_present
# preferred_stock_terms_Series 1A_present_present
# Saved CSV to: D:\vc-research\vc-research\Reese's contributions\reese data\downloaded_batches\combined_extracted_dataAICoded.csv
